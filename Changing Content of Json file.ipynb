# %%
import json
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## For Modifying Tags

# %%
directory_path ="/content/drive/MyDrive/CvipCodeFolder/assets"
for filename in os.listdir(directory_path):
    if filename.endswith(".json"):  # Only process JSON files
        # Construct the full file path
        file_path = os.path.join(directory_path, filename)
        # Read the file contents
        with open(file_path, "r") as file:
            file_contents = json.load(file)
        for i in file_contents["regions"]:
            tag=i["tags"]
            if(tag[0][1]!="b"):
                new_tag=tag[0].strip('a')
                new_tag=new_tag+"b"
                new_tag=[new_tag]
                i["tags"]=new_tag
                with open(file_path,"w") as file:
                    json.dump(i["tags"],file,indent=4)
                print("Tag Changed")
        # Modify the contents as desired
        path=file_contents["asset"]["path"]
        path=path.split("/")
        filename=path[-1]
        new_path="/content/drive/MyDrive/CvipCodeFolder/images"+'/'+filename 
        file_contents["asset"]["path"] = new_path
        # Write the modified contents back to the file
        with open(file_path, "w") as file:
            json.dump(file_contents, file, indent=4)
        print(f"Changed contents in {file_path}")
# Out:
# Changed contents in /content/drive/MyDrive/CvipCodeFolder/assets/334717b9ba2a74c5312a3de8c6cac5f8-asset.json
# Changed contents in /content/drive/MyDrive/CvipCodeFolder/assets/2eff8a1948549f90d1a08545f9fb5198-asset.json
# Changed contents in /content/drive/MyDrive/CvipCodeFolder/assets/09148d4f1eca20dfc07fc09aaa69cdfe-asset.json
# Changed contents in /content/drive/MyDrive/CvipCodeFolder/assets/11ee7846e6665c3f8cd8714aedeb9d6f-asset.json
# Changed contents in /content/drive/MyDrive/CvipCodeFolder/assets/151dfee13a5d248b099849772c26fc36-asset.json
# Changed contents in /content/drive/MyDrive/CvipCodeFolder/assets/1ef7d134e791bec1ad568ec2ccd93b79-asset.json
# Changed contents in /content/drive/MyDrive/CvipCodeFolder/assets/31c3a25c6d87e17e37781ece8cd52427-asset.json
# Changed contents in /content/drive/MyDrive/CvipCodeFolder/assets/0d94b458caf0acc531eb2da82f49588d-asset.json
# Changed contents in /content/drive/MyDrive/CvipCodeFolder/assets/2f228b5dc4b55cb5a8497563dd4fed2a-asset.json
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
